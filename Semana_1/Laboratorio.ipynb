# %%
# !git clone https://github.com/Edd1enator/marketing-analytics-eddie-giron.git
# Out:
# Cloning into 'marketing-analytics-eddie-giron'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 21 (delta 8), reused 20 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), done.
# Resolving deltas: 100% (8/8), done.

# %%
# !cd marketing-analytics-eddie-giron/Semana_1/
# !pip install streamlit scikit-learn pandas numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 90.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 95.3 MB/s eta 0:00:00
# ...

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

variable_x = np.array([[10], [20], [30], [40],[50]])
variable_y = np.array([15,25,35,45,55])

modelo_lr = LinearRegression()
modelo_lr.fit(variable_x,variable_y)

gasto = 100
resultado = modelo_lr.predict([[gasto]])

print(f"Las ventas proyectadas para una inversión de ${gasto} son: ${resultado[0]}")
# Out:
# Las ventas proyectadas para una inversión de $100 son: $105.0
